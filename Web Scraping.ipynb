# %% [markdown]
# # WEB SCRAPPING

# %% [markdown]
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites.[1] Web scraping software may directly access the World Wide Web using the Hypertext Transfer Protocol or a web browser. While web scraping can be done manually by a software user, the term typically refers to automated processes implemented using a bot or web crawler. It is a form of copying in which specific data is gathered and copied from the web, typically into a central local database or spreadsheet, for later retrieval or analysis.

# %%
# pip install bs4 (converts html/json/xml into string to perform analysis)

# %%
import bs4
import requests#(helps in extracting data from website)

# %%
url='https://blog.nextideatech.com/'
data=requests.get( url)

# %%
data
# Out:
# <Response [200]>

# %% [markdown]
# #respose 200 shows that data extracted successfully

# %% [markdown]
# #if response is 404 /500 (data is being restricted ex-flipkart,amazon)

# %%
soup=bs4.BeautifulSoup(data.text,'html.parser')# converts html to string(to know html or json go to inspect option)
print(soup.prettify())# for proper format use prettify
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Inter&amp;family=Manrope:wght@400;500;600;700&amp;display=swap" rel="stylesheet"/>
#   <link href="https://blog.nextideatech.com/xmlrpc.php" rel="pingback">
#    <script type="text/javascript">
#     document.documentElement.className = 'js';
#    </script>
#    <style id="editorskit-typography-inline-css">
#    </style>
#    <meta content="index, max-image-preview:large" name="robots">
#     <script type="text/javascript">
# ...

# %% [markdown]
# # To know total Para

# %%
for para in soup.find('p'):#find gives one para pr first para
    print(para)
# Out:
# Learn how to build software engineering teams with our Nearshore Services, latest development trends, remote work and much more...

# %%
for para in soup.find_all('p'):
    print(para)
# Out:
# <p>Learn how to build software engineering teams with our Nearshore Services, latest development trends, remote work and much more...</p>
# <p>Nearshore Outsourcing</p>
# <p>Remote Work</p>
# <p>Development Trends</p>
# <p>Recruiting Insights</p>
# <p class="featured">
# 													Featured
# 												</p>
# <p class="post-title"><a href="https://blog.nextideatech.com/healthcare-it-outsourcing-to-latin-america/">Healthcare IT Outsourcing to Latin America</a> </p>
# <p class="autho"><i class="fas fa-user-alt"></i><span class="entry-date">
# 														Low inpatient volume—combined with soaring labor costs and high interest rates—are putting increased pressure on some of the nation’s hospitals and health systems. In response, some healthcare organizations are shipping non-core clinical functions such													</span></p>
# <p class="autoho">
# <span class="entry-date">November 25, 2024</span></p>
# ...

# %%
#we dont need code of html
for para in soup.find_all('p'):
    
    print(para.text)
    print()
# Out:
# Learn how to build software engineering teams with our Nearshore Services, latest development trends, remote work and much more...
#
# Nearshore Outsourcing
#
# Remote Work
#
# Development Trends
#
# Recruiting Insights
#
#
# 													Featured
#
#
# Healthcare IT Outsourcing to Latin America
#
#
# 														Low inpatient volume—combined with soaring labor costs and high interest rates—are putting increased pressure on some of the nation’s hospitals and health systems. In response, some healthcare organizations are shipping non-core clinical functions such
#
#
# November 25, 2024
#
# November 25, 2024
#
# 12 minutes read
#
# November 25, 2024
#
# 15 minutes read
#
# November 25, 2024
#
# 12 minutes read
#
# October 17, 2024
#
# 11 minutes read
#
# October 17, 2024
#
# 10 minutes read
#
# September 10, 2024
#
# 12 minutes read
#
# September 8, 2024
#
# 11 minutes read
#
# September 8, 2024
#
# 23 minutes read
#
# September 8, 2024
#
# 8 minutes read
#
# August 12, 2024
#
# ...

# %% [markdown]
# # To Print Headings

# %%
for heading in soup.find_all('h2'):
    print(heading.text)
    print()
# Out:
# Healthcare IT Outsourcing to Latin America
#
# Fintech Software Development in Latin America
#
# How to Hire Reliable Software Developers in Latin America
#
# The Cost Savings and Business Benefits of Next Idea Tech
#
# Increase Developer Productivity With Generative AI
#
# What is a Nearshore LatAm Development Center
#
# How to Build LatAm Nearshore Development Teams
#
# How to Outsource Software Developers from LatAm
#
# 7 Benefits of Building LatAm Nearshore Teams
#
# Expand Your Business with LATAM Nearshoring
#
# Recommended

# %% [markdown]
# # To Print Links

# %%
li=[]
for link in soup.find_all('a'):
    link=link.get('href')
    li.append(link)
    print(li)
    print()
# Out:
# ['https://nextideatech.com/']
#
# ['https://nextideatech.com/', 'https://www.nextideatech.com/']
#
# ['https://nextideatech.com/', 'https://www.nextideatech.com/', 'https://www.nextideatech.com/vetting/']
#
# ['https://nextideatech.com/', 'https://www.nextideatech.com/', 'https://www.nextideatech.com/vetting/', 'https://blog.nextideatech.com/']
#
# ['https://nextideatech.com/', 'https://www.nextideatech.com/', 'https://www.nextideatech.com/vetting/', 'https://blog.nextideatech.com/', 'https://clutch.co/profile/next-idea-tech#reviews']
#
# ['https://nextideatech.com/', 'https://www.nextideatech.com/', 'https://www.nextideatech.com/vetting/', 'https://blog.nextideatech.com/', 'https://clutch.co/profile/next-idea-tech#reviews', 'https://www.nextideatech.com/faqs']
#
# ...

# %%
top_five_links=li[:5]
top_five_links
# Out:
# ['https://nextideatech.com/',
#  'https://www.nextideatech.com/',
#  'https://www.nextideatech.com/vetting/',
#  'https://blog.nextideatech.com/',
#  'https://clutch.co/profile/next-idea-tech#reviews']

# %%
# to open these 5 links automatically use webbrowser
import webbrowser

# %%
for i in top_five_links:
    webbrowser.open(i)
